# %%
a = 3
b = 'test'
print(str(a) + b)
# Out:
# 3test

# %%
int( float(a) )
# Out:
# 3

# %%
sum = 0
for num in range(1,11):
    print(f"Loop No.{num}")
    # print('sum: ' + str(sum))
    # print("sum: ", sum)
    print(f"sum: {sum}")
    print(f"num: {num}")
    sum = sum + num
    print(f"누적합: {sum}")
    # print(sum)
# Out:
# Loop No.1
# sum: 0
# num: 1
# 누적합: 1
# Loop No.2
# sum: 1
# num: 2
# 누적합: 3
# Loop No.3
# sum: 3
# num: 3
# 누적합: 6
# Loop No.4
# sum: 6
# num: 4
# 누적합: 10
# Loop No.5
# sum: 10
# num: 5
# 누적합: 15
# Loop No.6
# sum: 15
# num: 6
# 누적합: 21
# Loop No.7
# sum: 21
# num: 7
# 누적합: 28
# Loop No.8
# sum: 28
# num: 8
# 누적합: 36
# Loop No.9
# sum: 36
# num: 9
# 누적합: 45
# Loop No.10
# sum: 45
# num: 10
# 누적합: 55

# %%
test = ['3',"6",'9',12,'''15''']

# %%
test[1] + test[2]
# Out:
# '69'

# %%
type(test)
# Out:
# list

# %%
type(test[4])
# Out:
# str

# %%
print(len(test))
# Out:
# 5

# %%
test = [3,4,5,6,7]
idx = 0
length = len(test)
while idx < length:
    print('=======while sample start=======', end = ' | ')
    print(f'{idx} value: {test[idx]}', end = ' | ')
    print('=======while sample end=======', end = ' | ')
    idx += 1  # idx = idx + 1
# Out:
# =======while sample start======= | 0 value: 3 | =======while sample end======= | =======while sample start======= | 1 value: 4 | =======while sample end======= | =======while sample start======= | 2 value: 5 | =======while sample end======= | =======while sample start======= | 3 value: 6 | =======while sample end======= | =======while sample start======= | 4 value: 7 | =======while sample end======= |

# %%
print(3, end = ' | ')
print(4)
print(5)
# Out:
# 3 | 4
# 5

# %%
test = [3,4,5,6,7]
idx = 0
length = len(test)
while idx < length:
    print(f'{idx} value: {test[idx]}', end = ' | ')
    idx += 1  # idx = idx + 1
# Out:
# 0 value: 3 | 1 value: 4 | 2 value: 5 | 3 value: 6 | 4 value: 7 |

# %%
test[1] = 100*0.03

# %%
test
# Out:
# [3, 3.0, 5, 6, 7]

# %%
import numpy as np

# %%
print(np.array(test))
# Out:
# [3. 3. 5. 6. 7.]

# %%
print(test)
# Out:
# [3, 3.0, 5, 6, 7]

# %%
test.append(7)
print(test)
# Out:
# [3, 3.0, 5, 6, 7, 7]

# %%
test.remove(7)
print(test)
# Out:
# [3, 3.0, 5, 6, 7]

# %%
(1,2)+(3,4)
# Out:
# (1, 2, 3, 4)

# %%
test = (1,2,3,4)

# %%
type(test)
# Out:
# tuple

# %%
test[1]
# Out:
# 2

# %%
test+(5,6,7)
# Out:
# (1, 2, 3, 4, 5, 6, 7)

# %%
test.append(5,6,7)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 test.append(5,6,7)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
test + (1,)
# Out:
# (1, 2, 3, 4, 1)

# %%
robot = {
    "name": "turtlebot",
    "battery": 50,
    "speed": 1.2
}

# %%
type(robot)
# Out:
# dict

# %%
a = {1,2,3,4,3,2,1}

# %%
print(type(a))
print(a)
# Out:
# <class 'set'>
# {1, 2, 3, 4}

# %%
a[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 a[1]
#
# TypeError: 'set' object is not subscriptable

# %%
robot["speed"]
# Out:
# 1.2

# %%
sensor = list(robot.keys())

# %%
for n in sensor:
    print(n)
# Out:
# name
# battery
# speed
# 0

# %%
type(sensor)
# Out:
# list

# %%
sensor[0]
# Out:
# 'name'

# %%
robot.values
# Out:
# <function dict.values>

# %%
list(robot.values())
# Out:
# ['testbot', 50, 1.2, 'test']

# %%
robot.pop(0)
# Out:
# 'test'

# %%
data = list(robot.items())

# %%
data
# Out:
# [('name', 'testbot'), ('battery', 50), ('speed', 1.2)]

# %%
data[0]
# Out:
# ('name', 'testbot')
